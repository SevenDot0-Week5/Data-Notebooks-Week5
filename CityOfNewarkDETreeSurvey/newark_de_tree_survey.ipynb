# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read a comma-separated values (csv) file into DataFrame.
#
# The data folder contains a file named "newark_tree_data.csv". Read this file into a dataframe.
#
#
# resources:
# * [Pandas read csv docs](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html#pandas.read_csv)

# %%
# Create DataFrame here.

df = pd.read_csv("data/newark_tree_data.csv")

# %%
# Display the first few rows of the DataFrame here.
df.head()
# Out:
#      ID         ON       AREA  ADDRESS       STREET  SITE   SIDE  ASSIGNED  \
# 0  11.0  Elan Park  Elan Park        2  Blue Hen Rg  11.0  Front     False
# 1  12.0  Elan Park  Elan Park        2  Blue Hen Rg  12.0  Front     False
# 2  13.0  Elan Park  Elan Park        2  Blue Hen Rg  13.0  Front     False
# 3  14.0  Elan Park  Elan Park        2  Blue Hen Rg  14.0  Front     False
# 4  15.0  Elan Park  Elan Park        2  Blue Hen Rg  15.0  Front     False
#
#                  COMMON               BOTANICAL  ... IMPROPMULC  IMPROPPRUN  \
# 0   arborvitae, eastern      Thuja occidentalis  ...      False       False
# 1   arborvitae, eastern      Thuja occidentalis  ...      False       False
# 2   pine, eastern white           Pinus strobus  ...      False       False
# 3  whitecedar, Atlantic  Chamaecyparis thyoides  ...      False       False
# 4  whitecedar, Atlantic  Chamaecyparis thyoides  ...      False       False
#
#   NUTRIENTD   PEST GIRDLING STRESS  OHUTILITY  TOP_HEIGHT CROWN_M CROWN_DIE
# 0     False  False    False  False         No          40    0-5%      0-5%
# 1     False  False    False  False         No          41    0-5%      0-5%
# 2     False  False     True  False         No          54    0-5%     6-10%
# 3     False  False     True  False         No          57  11-15%    26-30%
# 4     False  False     True  False         No          55  11-15%    21-25%
#
# [5 rows x 54 columns]

# %%
# How many columns does the DataFrame contain?
len(df.columns)
# Out:
# 54

# %%
# What attributes (columns) does this DataFrame contain?
df.columns
# Out:
# Index(['ID', 'ON', 'AREA', 'ADDRESS', 'STREET', 'SITE', 'SIDE', 'ASSIGNED',
#        'COMMON', 'BOTANICAL', 'CULTIVAR', 'DBH', 'REMOVAL', 'STEMS', 'COND',
#        'MAINTPRIM', 'OBSERVE', 'INSPECT', 'LOCATION', 'NOTES', 'DATE', 'TIME',
#        'STAFF', 'XCOORD', 'YCOORD', 'FAILURE', 'LIKELIHOOD', 'TARGET',
#        'CONSEQ', 'RISK', 'UNIQUEID', 'EDITTIME', 'SPREAD', 'HEIGHT',
#        'CLEARANCE', 'DECAYCL', 'DECAYT', 'DECAYRF', 'DAMC', 'DAMT', 'DAMRF',
#        'CAVITYCL', 'CAVITYT', 'CAVITYRF', 'IMPROPMULC', 'IMPROPPRUN',
#        'NUTRIENTD', 'PEST', 'GIRDLING', 'STRESS', 'OHUTILITY', 'TOP_HEIGHT',
#        'CROWN_M', 'CROWN_DIE'],
#       dtype='str')

# %% [markdown]
# Upon reviewing the columns of the DataFrame, we see that there is already a column named ID that is well suited for an index column.
#
# For the purposes of this lab, we are only going to need a few of the available attributes. The attributes we wish to keep are listed below:
# * ID
# * UNIQUEID
# * COMMON
# * BOTANICAL
# * COND
# * RISK
# * HEIGHT
#
# Let's provide the index_col and the usecols args when we invoke the read_csv method.

# %%
# Create the new DataFrame here.
new_df = df[["ID", "UNIQUEID", "COMMON", "BOTANICAL", "COND", "RISK", "HEIGHT"]]

# %%
# Display the first few rows of the new DataFrame here.
new_df.head()
# Out:
#      ID           UNIQUEID                COMMON               BOTANICAL  \
# 0  11.0  LM 20150929141218   arborvitae, eastern      Thuja occidentalis
# 1  12.0  LM 20150929141418   arborvitae, eastern      Thuja occidentalis
# 2  13.0  LM 20150929141844   pine, eastern white           Pinus strobus
# 3  14.0  LM 20150929142424  whitecedar, Atlantic  Chamaecyparis thyoides
# 4  15.0  LM 20150929143018  whitecedar, Atlantic  Chamaecyparis thyoides
#
#         COND RISK  HEIGHT
# 0       Good  Low      40
# 1  Very Good  Low      40
# 2       Good  Low      54
# 3       Fair  Low      56
# 4       Fair  Low      55

# %% [markdown]
# The data narritive specifies that 4,193 sites were inventoried. Use the DataFrame shape attribute to verify the number of rows.

# %%
# How many rows does your DataFrame contain.
len(new_df)
# Out:
# 4193

# %% [markdown]
# Let's look at the distribution of data for the HEIGHT attribute.

# %%
# What is the min height?
new_df["HEIGHT"].min()
# Out:
# np.int64(0)

# %%
# What is the max height?
new_df["HEIGHT"].max()
# Out:
# np.int64(140)

# %%
# How do we acquire count, mean, standard deviation, and distribution information from the DataFrame 
# by invoking a single method?
new_df.describe()
# Out:
#                 ID       HEIGHT
# count  4193.000000  4193.000000
# mean   2097.000000    55.311472
# std    1210.559168    36.293489
# min       1.000000     0.000000
# 25%    1049.000000    23.000000
# 50%    2097.000000    50.000000
# 75%    3145.000000    86.000000
# max    4193.000000   140.000000

# %% [markdown]
# # Plot a histogram using the HEIGHT attribute.
#
# resources:
# * [Magic commands](https://ipython.readthedocs.io/en/stable/interactive/magics.html)
# * [Pandas Series Hist](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.hist.html#pandas.Series.plot.hist)

# %%
# Apply magic command to display matplotlib images inline
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Apply magic command to display matplotlib images inline
# ----> 2 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File ~/.venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py:2532, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2530     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2531 with self.builtin_trap:
# -> 2532     result = fn(*args, **kwargs)
#    2534 # The code below prevents the output from being displayed
#    2535 # when using magics with decorator @output_can_be_silenced
#    2536 # when the last Python token in the expression is a ';'.
#    2537 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.venv/lib/python3.14/site-packages/IPython/core/magics/pylab.py:103, in PylabMagics.matplotlib(self, line)
#      98     print(
#      99         "Available matplotlib backends: %s"
#     100         % _list_matplotlib_backends_and_gui_loops()
#     101     )
#     102 else:
# --> 103     gui, backend = self.shell.enable_matplotlib(args.gui)
#     104     self._show_matplotlib_backend(args.gui, backend)
#
# File ~/.venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py:3835, in InteractiveShell.enable_matplotlib(self, gui)
#    3832     import matplotlib_inline.backend_inline
#    3834 from IPython.core import pylabtools as pt
# -> 3835 gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3837 if gui != None:
#    3838     # If we have our first gui selection, store it
#    3839     if self.pylab_gui_select is None:
#
# File ~/.venv/lib/python3.14/site-packages/IPython/core/pylabtools.py:338, in find_gui_and_backend(gui, gui_select)
#     321 def find_gui_and_backend(gui=None, gui_select=None):
#     322     """Given a gui string return the gui and mpl backend.
#     323
#     324     Parameters
#    (...)    335     'WXAgg','Qt4Agg','module://matplotlib_inline.backend_inline','agg').
#     336     """
# --> 338     import matplotlib
#     340     if _matplotlib_manages_backends():
#     341         backend_registry = matplotlib.backends.registry.backend_registry
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Create a histogram using the HEIGHT attribute here

# %% [markdown]
# The data narrative specifies the following:
# "A total of 4,193 sites were inventoried, including 4,087 trees, 100 stumps, and 6 vacant planting sites"
#
# Earlier, we were able to validate the total number of entries in the DataFrame. Let's now dig in a bit deeper and validate the stumps and vacant planting sites.

# %%
# How many entries are stumps

# %%
# How many entries are vacant sites

# %%
# Do these number add up?

# %% [markdown]
# # Plot a bar graph using the COND attribute.
#
# resources:
# * [Pandas Series Bar](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.bar.html#pandas.Series.plot.bar)

# %%
# How can we determine all of the possible values describing the condition of a tree and their associated counts?

# %%
# Were these already in the order you would want them to be in order for a graph to make sense? 
# If not, reorder  the Series.

# %%
# Plot the Series here

# %%
# How many entries have missing values for the COND attribute? Why are these values missing?

# %% [markdown]
# # Plot a pie chart using the RISK attribute.

# %% [markdown]
# resources:
# * [Pandas Series Pie](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.pie.html#pandas.Series.plot.pie)
# * [matplotlib pie chart docs](https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie)

# %%
# How can we determine all of the possible values describing the RISK associated with each tree
# along with the corresponding row counts?

# %%
# Create an array containing the colors green, yellow, and orange
# When we create our pie chart, the colors should be associated with the attributes according to the specifications below:
# Green -> Low
# Yellow -> Moderate
# Orange -> High

# %%
# Plot the pie chart here

# %%
# How many entries have missing values for the RISK attribute? Why are these values missing?

# %% [markdown]
# # Indexing

# %%
# Display row by position 1

# %%
# Display row by label 1
